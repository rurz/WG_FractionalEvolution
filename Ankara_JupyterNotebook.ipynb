# %%
include("tests/Ankara.jl")

# %%
fig1 = figure(figsize = (10,5))
ax1 = gca()
ax1.imshow(Ankara, cmap = "hot")
ax1.set_aspect("auto")

tight_layout()
# Out:
# Figure(PyObject <Figure size 1000x500 with 1 Axes>)
